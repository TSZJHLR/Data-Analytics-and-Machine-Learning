# %% [markdown]
# # [Group Assignment | Spetember - December 2024]
# ## CASE STUDY ON TRAVEL AND TOURISM | TREKKING IN NEPAL
#
# > ITS69304 - Data Analytics & Machine Learning
#
# > ITS69404 - Cognitive Computing & Appliciations

# %% [markdown]
# ## authorization

# %% [markdown]
# ### install

# %% [markdown]
# #### gspread

# %%
# !pip install --upgrade gspread

# %% [markdown]
# ### import

# %% [markdown]
# #### authentication

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# #### mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### gspread and default

# %%
import gspread
from google.auth import default
creds, _ = default()

# %% [markdown]
# #### pandas

# %%
import pandas as pd

# %% [markdown]
# ## first look

# %% [markdown]
# ### sheets command

# %% [markdown]
# #### list all available spreadsheets

# %%
# for file in gc.list_spreadsheet_files():
#   print(file['name'])

# %% [markdown]
# #### open 'Nepal Treking'

# %%
gc = gspread.authorize(creds)
worksheet = gc.open('Nepali_Treking_').sheet1

# %% [markdown]
# #### convert the  records of rows into dataframe

# %%
rows = worksheet.get_all_values()
df1 = pd.DataFrame.from_records(rows)

# %% [markdown]
# ## manipualtion

# %% [markdown]
# #### checking df1

# %%
display(df1)
# Out:
#              0                                    1                 2   \
# 0    Unnamed: 0                                 Trek              Cost
# 1             0               Everest Base Camp Trek  \n$1,420     USD
# 2             1         Everest Base Camp Short Trek  \n$1,295     USD
# 3             2  Everest Base Camp Heli Shuttle Trek       \n$2000 USD
# 4             3          Everest Base Camp Heli Trek  \n$3,300     USD
# ..          ...                                  ...               ...
# 379         378             Ghorepani Poon Hill Trek          $450 USD
# 380         379                   Upper Mustang Trek         $2100 USD
# 381         380                     Mardi Himal Trek          $590 USD
# 382         381             Langtang Valley Trekking          $690 USD
# 383         382                 Manaslu Circuit Trek         $1190 USD
#
#           3              4             5                 6   \
# ...

# %% [markdown]
# #### retrive value from dataframe with index number

# %%
df1.iloc[0]
# Out:
# 0              Unnamed: 0
# 1                    Trek
# 2                    Cost
# 3                    Time
# 4              Trip Grade
# 5            Max Altitude
# 6            Accomodation
# 7        Best Travel Time
# 8          Date Of Travel
# 9                     Sex
# 10                    Age
# 11        Employment Type
# 12          GraduateOrNot
# 13           AnnualIncome
# 14          FamilyMembers
# 15        ChronicDiseases
# 16          FrequentFlyer
# 17    EverTravelledAbroad
# 18        TravelInsurance
# 19                   Year
# 20           RegionalCode
# 21                Country
# 22           FitnessLevel
# 23     Weather Conditions
# 24    Trekking Group Size
# 25         Guide No Guide
# 26         Equipment Used
# 27      Purpose Of Travel
# 28       Health Incidents
# 29    Review Satisfaction
# Name: 0, dtype: object

# %% [markdown]
# #### drop first column

# %%
df2 = df1.drop(columns=df1.columns[0])

# %% [markdown]
# #### setting/assigning column name of df to first row and removing the previous first row

# %%
df2.columns = df2.iloc[0]
df2 = df2[1:]

# %% [markdown]
# #### checking datatypes

# %%
print(df2.dtypes)
# Out:
# 0
# Trek                   object
# Cost                   object
# Time                   object
# Trip Grade             object
# Max Altitude           object
# Accomodation           object
# Best Travel Time       object
# Date Of Travel         object
# Sex                    object
# Age                    object
# Employment Type        object
# GraduateOrNot          object
# AnnualIncome           object
# FamilyMembers          object
# ChronicDiseases        object
# FrequentFlyer          object
# EverTravelledAbroad    object
# TravelInsurance        object
# Year                   object
# RegionalCode           object
# Country                object
# FitnessLevel           object
# Weather Conditions     object
# Trekking Group Size    object
# Guide No Guide         object
# Equipment Used         object
# Purpose Of Travel      object
# Health Incidents       object
# Review Satisfaction    object
# dtype: object

# %% [markdown]
# #### checking list of column names

# %%
display(df2.columns)
# Out:
# Index(['Trek', 'Cost', 'Time', 'Trip Grade', 'Max Altitude', 'Accomodation',
#        'Best Travel Time', 'Date Of Travel', 'Sex', 'Age', 'Employment Type',
#        'GraduateOrNot', 'AnnualIncome', 'FamilyMembers', 'ChronicDiseases',
#        'FrequentFlyer', 'EverTravelledAbroad', 'TravelInsurance', 'Year',
#        'RegionalCode', 'Country', 'FitnessLevel', 'Weather Conditions',
#        'Trekking Group Size', 'Guide No Guide', 'Equipment Used',
#        'Purpose Of Travel', 'Health Incidents', 'Review Satisfaction'],
#       dtype='object', name=0)

# %% [markdown]
# #### checking dataframe info

# %%
display(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 1 to 383
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Trek                 383 non-null    object
#  1   Cost                 383 non-null    object
#  2   Time                 383 non-null    object
#  3   Trip Grade           383 non-null    object
#  4   Max Altitude         383 non-null    object
#  5   Accomodation         383 non-null    object
#  6   Best Travel Time     383 non-null    object
#  7   Date Of Travel       383 non-null    object
#  8   Sex                  383 non-null    object
#  9   Age                  383 non-null    object
#  10  Employment Type      383 non-null    object
#  11  GraduateOrNot        383 non-null    object
#  12  AnnualIncome         383 non-null    object
#  13  FamilyMembers        383 non-null    object
#  14  ChronicDiseases      383 non-null    object
# ...

# %% [markdown]
# #### using describe function

# %%
display(df2.describe())
# Out:
# 0                           Trek             Cost     Time Trip Grade  \
# count                        383              383      383        383
# unique                        79              167       20         11
# top     Annapurna Base Camp Trek   $1,499     USD  14 Days   Moderate
# freq                          10               36       56         92
#
# 0      Max Altitude      Accomodation        Best Travel Time Date Of Travel  \
# count           383               383                     383            383
# unique           43                 8                      13            332
# top          5,545m  Hotel/Guesthouse  Jan - May & Sept - Dec      4/11/2022
# freq             55               312                     262              3
#
# 0          Sex  Age  ... RegionalCode Country FitnessLevel Weather Conditions  \
# count      383  383  ...          383     383          383                383
# ...

# %% [markdown]
# #### check the shape of dataframe

# %%
print(df2.shape)
# Out:
# (383, 29)

# %% [markdown]
# #### checking is null array

# %%
print(df2.columns.isnull())
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]

# %% [markdown]
# #### checking total number of null values

# %%
print(df2.isnull().sum())
# Out:
# 0
# Trek                   0
# Cost                   0
# Time                   0
# Trip Grade             0
# Max Altitude           0
# Accomodation           0
# Best Travel Time       0
# Date Of Travel         0
# Sex                    0
# Age                    0
# Employment Type        0
# GraduateOrNot          0
# AnnualIncome           0
# FamilyMembers          0
# ChronicDiseases        0
# FrequentFlyer          0
# EverTravelledAbroad    0
# TravelInsurance        0
# Year                   0
# RegionalCode           0
# Country                0
# FitnessLevel           0
# Weather Conditions     0
# Trekking Group Size    0
# Guide No Guide         0
# Equipment Used         0
# Purpose Of Travel      0
# Health Incidents       0
# Review Satisfaction    0
# dtype: int64

# %%
print(df2.isna().sum())
# Out:
# 0
# Trek                   0
# Cost                   0
# Time                   0
# Trip Grade             0
# Max Altitude           0
# Accomodation           0
# Best Travel Time       0
# Date Of Travel         0
# Sex                    0
# Age                    0
# Employment Type        0
# GraduateOrNot          0
# AnnualIncome           0
# FamilyMembers          0
# ChronicDiseases        0
# FrequentFlyer          0
# EverTravelledAbroad    0
# TravelInsurance        0
# Year                   0
# RegionalCode           0
# Country                0
# FitnessLevel           0
# Weather Conditions     0
# Trekking Group Size    0
# Guide No Guide         0
# Equipment Used         0
# Purpose Of Travel      0
# Health Incidents       0
# Review Satisfaction    0
# dtype: int64

# %% [markdown]
# #### checking df2

# %%
display(df2)
# Out:
# 0                                   Trek              Cost     Time  \
# 1                 Everest Base Camp Trek  \n$1,420     USD  16 Days
# 2           Everest Base Camp Short Trek  \n$1,295     USD  14 Days
# 3    Everest Base Camp Heli Shuttle Trek       \n$2000 USD  12 Days
# 4            Everest Base Camp Heli Trek  \n$3,300     USD  11 Days
# 5     Everest Base Camp Trek for Seniors  \n$1,800     USD  20 Days
# ..                                   ...               ...      ...
# 379             Ghorepani Poon Hill Trek          $450 USD  10 Days
# 380                   Upper Mustang Trek         $2100 USD  17 Days
# 381                     Mardi Himal Trek          $590 USD   9 Days
# 382             Langtang Valley Trekking          $690 USD  11 Days
# 383                 Manaslu Circuit Trek         $1190 USD  17 Days
#
# 0       Trip Grade Max Altitude      Accomodation          Best Travel Time  \
# ...

# %%
df2.to_csv('/content/drive/MyDrive/iims/sem6/group 6 project/datasets/df2.csv', index=False)
